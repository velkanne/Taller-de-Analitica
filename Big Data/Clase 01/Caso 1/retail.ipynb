# %%
import pandas as pd

# %%
retail_data = {
    'ID Venta': [501, 502, 501, 503, 504, 505, 501, 506, 501, 508],
    'Fecha': ['01/03/2026', '2026-03-01', '01-03-26', '02/03/2026', '02/03/2026', '03/03/2026', '01/03/2026', '03/03/2026', '01/03/2026', '04/03/2026'],
    'Monto_CLP': [450000, None, 450000, 120000, 85000, 990000, 450000, 15000, 450000, 45000],
    'Depto': ['COMPUTACION', 'Smartphones', 'COMPUTACION', 'Audio', None, 'Computacion', 'COMPUTACION', 'smartphones', 'COMPUTACION', 'AUDIO']
}

pd.DataFrame(retail_data).to_csv('retail.csv', index=False)

print("Archivo 'retail.csv' creado con éxito.")
# Out:
# Archivo 'retail.csv' creado con éxito.

# %%
df = pd.read_csv("retail.csv")

print("1. Total de Registros")
print(f"Filas: {df.shape[0]}")

print("n\2 Deteccion de Duplicados")
print(f"Total filas duplicados: {df.duplicated().sum()}")

print("n\3 Deteccion de Nulos")
print(df.isnull().sum())

print("n\4 Deteccion de Inconsistencias")
print(df["Depto"].unique())
# Out:
# 1. Total de Registros
# Filas: 10
# n Deteccion de Duplicados
# Total filas duplicados: 2
# n Deteccion de Nulos
# ID Venta     0
# Fecha        0
# Monto_CLP    1
# Depto        1
# dtype: int64
# n Deteccion de Inconsistencias
# ['COMPUTACION' 'Smartphones' 'Audio' nan 'Computacion' 'smartphones'
#  'AUDIO']

# %%
#cuantas filas hay?
